# %% [markdown]
# # Creating functions in Python (for scraping)
#
# In previous notebooks we covered:
#
# * How to create variables in Python (to store things like URLs for scraping, and the data from pages that we scrape);
# * How to loop through lists (in order to scrape or store each item in that list, for example); and
# * How to create data frames using `pandas` (to store the scraped data).
#
# Now we're going to bring those together into a final multi-page scraper by creating our own **functions**.
#
# We've used functions already such as `sum()` and `len()`. These are **built-in functions** that come with Python.
#
# We've also used functions from libraries, like `pd.read_csv()` and `BeautifulSoup()`.
#
# You can create your own function - a **user-defined function** - with the `def` command like so:

# %%
def sayhello():
  print("hello")

# %% [markdown]
# The `def` command is followed by:
#
# * The name of the function
# * Parentheses (which can contain any ingredients that you want to use but in this example don't)
# * A colon, and
# * Indented lines of code underneath which will run when the function is used
#
# The name of the function is entirely up to you, but try to make it distinctive and meaningful.
#
# We will explain the other parts as we begin to create a function below, but note for now that when you create the function nothing appears to happen.
#
# Of course something *has* happened when you run the code above: a function has been created and can now be used.

# %% [markdown]
# ## 'Calling' a function
#
# Using a function is referred to as 'calling' it.
#
# This is how you **call** a function:

# %%
sayhello()
# Out:
# hello

# %% [markdown]
# Basically it's like any other function: you type the name of the function, followed by parentheses containing any ingredients it needs. Even if the function doesn't need any ingredients, you still use (empty) parentheses.

# %% [markdown]
# ## Creating a function with ingredients
#
# Our example so far didn't have any ingredients, so let's create one that does.

# %%
def print_this_word(thisword):
  print(thisword)

# %% [markdown]
# This time we've put a word inside the parentheses: `thisword`
#
# In a way, we've created a variable to store whatever ingredient is used when someone calls this function. (This is called a **parameter**.)
#
# That variable is then used in the code below: `print(thisword)`
#
# To see what happens, let's use that function:

# %%
print_this_word("pumpkin")
# Out:
# pumpkin

# %% [markdown]
# Now let's break down what happens when that line of code is run:
#
# 1. First, it **calls** the function `print_this_word`
# 2. Then it gives it an ingredient: the string "pumpkin". This is called **passing** an **argument**
# 3. When the function was written, it called that ingredient `thisword`, so the string "pumpkin" is stored in a variable called `thisword`
# 4. As the function code runs, it accesses that variable inside a `print()` command, so the contents of that variable ("pumpkin" this time) are printed

# %% [markdown]
# ## Creating a scraper that **returns** something
#
# Our scraper above only prints something, but often you want a scraper to do something (such as perform a calculation, or scrape a page) and then **return** the results.
#
# Here's an example:

# %%
#define a new function called 'addtwonumbers' which has 2 parameters (ingredients)
def addtwonumbers(numone, numtwo):
  #the two parameters are added together and stored in 'total'
  total = numone+numtwo
  #the function returns that value
  return(total)

# %% [markdown]
# You can see that this function has *two* ingredients (parameters): `numone` and `numtwo`, separated by a comma. The function adds those two together, and stores it in a new variable called `total`. Finally it specifies to `return()` the contents of that variable.
#
# Here's that function being used:

# %%
whatisit = addtwonumbers(3,8)
print(whatisit)
# Out:
# 11

# %% [markdown]
# You can see that the first line runs the `addtwonumbers()` function and **passes** it two ingredients: two numbers, 3 and 8.
#
# The function runs, adds those two numbers together, and *returns* the result to the variable that it was being used to create: `whatisit`.
#
# We then print that.
#
# Returning information from a function can be incredibly powerful: in the example above it was just a number that was returned, but you can return lists, dictionaries, multiple items, and, among other things, data frames - which is what happens next...

# %% [markdown]
# ## Creating a scraper function
#
# Now let's create a function to contain the code that we wrote for our scraper in a separate notebook.

# %%
#define a function
def scrapepage(theurl):
  #fetch the page from the URL
  page = requests.get(theurl)
  #parse the page into a 'soup' object
  soup = BeautifulSoup(page.content, 'html.parser')
  #grab all the headlines - we've identified a class attribute they all have
  headlines = soup.select('div a[class="gs-c-promo-heading gs-o-faux-block-link__overlay-link gel-pica-bold nw-o-link-split__anchor"]')
  #create two empty lists for the two pieces of information we want to extract
  headlinetext = []
  links = []
  #loop through them
  for i in headlines:
    #extract the text
    headtext = i.get_text()
    #extract the link
    headlink = i['href']
    #add the text to the previously empty list 
    headlinetext.append(headtext)
    #add the link to a second empty list
    links.append(headlink)
  #check that both are the same length
  print(len(headlinetext))
  print(len(links))
  #create a dataframe to store them
  df = pd.DataFrame({"headline" : headlinetext, "link" : links})
  return(df)

# %% [markdown]
# To create this function we've essentially taken all the important code from that notebook and indented it under the line `def scrapepage(theurl):`
#
# That first line transforms our previous code into something **reusable** by doing two things: giving a name to it (`scrapepage`); and giving a name to the URL we want to scrape (`theurl`).
#
# There's one other extra line too, right at the end: `return(df)` ensures that the results of the scraper are passed back to whatever calls this function.
#
# Something else to highlight: the function contains a `for` loop as well, which means there are two levels of indents in the code: all the code inside the function is indented, and then the `for` loop code inside *that* is indented one more time.

# %% [markdown]
# ## Calling the scraper function
#
# Now let's call that function on a bunch of pages. First we need to make sure the libraries are loaded.

# %%
#install the libraries 
import requests
from bs4 import BeautifulSoup
#the pandas library which is used to work with data 
import pandas as pd

# %% [markdown]
# ### Testing the scraper function on one URL
#
# Next we test it on just one URL.

# %%
#store the URL of another topic page (environment)
testurl = "https://www.bbc.co.uk/news/science-environment-56837908"
#run the function on that URL and store the results in 'testdf'
testdf = scrapepage(testurl)
#check what we have
testdf
# Out:
# 39
# 39
#                                              headline                                               link
# 0      Biggest coal plant in Australia to close early                            /news/business-60411622
# 1     More than eight million trees lost in UK winter                 /news/science-environment-60348947
# 2     Flooding is the new reality in Wales - watchdog                            /news/uk-wales-60386125
# 3     Big banks fund new oil despite net zero pledges                            /news/business-60366054
# 4      Record high deforestation of Amazon in January                 /news/science-environment-60333422
# 5           UK's only shale gas wells to be abandoned               /news/uk-england-lancashire-60341226
# 6      Biggest coal plant in Australia to close early                            /news/business-60411622
# 7     More than eight million trees lost in UK winter                 /news/science-environment-60348947
# 8     Flooding is the new reality in Wales - watchdog                            /news/uk-wales-60386125
# 9     Big banks fund new oil despite net zero pledges                            /news/business-60366054
# 10     Record high deforestation of Amazon in January                 /news/science-environment-60333422
# 11          UK's only shale gas wells to be abandoned               /news/uk-england-lancashire-60341226
# 12     Biggest coal plant in Australia to close early                            /news/business-60411622
# 13    More than eight million trees lost in UK winter                 /news/science-environment-60348947
# 14    Flooding is the new reality in Wales - watchdog                            /news/uk-wales-60386125
# 15    Big banks fund new oil despite net zero pledges                            /news/business-60366054
# 16     Record high deforestation of Amazon in January                 /news/science-environment-60333422
# 17          UK's only shale gas wells to be abandoned               /news/uk-england-lancashire-60341226
# 18                          What was agreed at COP26?                 /news/science-environment-56901261
# 19                  What do scientists actually want?                 /news/science-environment-59212185
# 20                 How the world is reacting to COP26                 /news/science-environment-59036722
# 21       Why China's climate policy matters to us all                    /news/world-asia-china-57483492
# 22     Key climate finance pledge pushed back to 2023                 /news/science-environment-59040538
# 23            A really simple guide to climate change                 /news/science-environment-24021772
# 24  How do we know climate change is caused by hum...                 /news/science-environment-58954530
# 25               How hot could it get where you live?  https://www.bbc.co.uk/news/resources/idt-d6338...
# 26               What's your diet's carbon footprint?                 /news/science-environment-46459714
# 27                           What does net zero mean?                 /news/science-environment-58874518
# 28         False banana offers hope for warming world                 /news/science-environment-60074407
# 29       'Megaberg' dumped huge volume of fresh water                 /news/science-environment-60060299
# 30     Marshland 'engineered' to fight climate change                 /news/science-environment-59241053
# 31              Why deforestation is such a hot topic                 /news/science-environment-58399809
# 32                   Pandemic lockdowns clear the air                 /news/science-environment-57149747
# 33               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 34               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 35               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 36              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 37            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 38            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...

# %% [markdown]
# ## Loop through multiple URLs and scrape them all
#
# Now we can try it on a list of URLs.
#
# This time we need to create an empty dataframe to store the results of each page.
#
# We also need to create a list of URLs that we want to loop through and scrape.
#
# Each time that we loop through the list, and grab one URL, we use `.append()` to add the dataframe of *one page's results* to the ongoing dataframe of *all results*.

# %%
#Create a dataframe to store the data we are about to scrape
allresults = pandas.DataFrame()

#create a list of URLs to scrape
urllist = ["https://www.bbc.co.uk/news/world","https://www.bbc.co.uk/news/health", "https://www.bbc.co.uk/news/entertainment_and_arts"]

#then loop through them and add to the URL
for i in urllist:
  #scrape that url
  df = scrapepage(i)
  print(df)
  #add the new data frame to the existing data frame
  allresults = allresults.append(df)

#print final dataframe
print(allresults)
# Out:
# 39
# 39
#                                              headline                                               link
# 0   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 1       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 2   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 3   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 4        Australia says China shone laser at warplane                     /news/world-australia-60446928
# 5      Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 6   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 7       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 8   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 9   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 10       Australia says China shone laser at warplane                     /news/world-australia-60446928
# 11     Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 12  Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 13      Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 14  Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 15  Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 16       Australia says China shone laser at warplane                     /news/world-australia-60446928
# 17     Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 18     US couple plead guilty in nuclear secrets plot                     /news/world-us-canada-60442225
# 19            Epstein ex-associate found dead in jail                        /news/world-europe-60443518
# 20     Ex-soldier given life for French girl's murder                        /news/world-europe-60416617
# 21  US ex-police officer jailed for gun mix-up sho...                     /news/world-us-canada-60436945
# 22  Hopes fade for survivors in Brazil's flood-hit...                 /news/world-latin-america-60426163
# 23  I dance to cope, says Ukrainian amid invasion ...                        /news/world-europe-60446826
# 24  The coach who gave Valieva a 'chilling' reception                    /sport/winter-olympics/60427119
# 25  The Instagram historians chronicling Delhi's past                    /news/world-asia-india-60299136
# 26                   When suspicion gets crowdsourced                     /news/world-us-canada-60091787
# 27             The role of stomachs in electioneering                        /news/world-africa-60023007
# 28  Video 1 minute 6 secondsBiden: I'm convinced P...                     /news/world-us-canada-60440241
# 29  Video 2 minutes 36 seconds'My son's killer nev...                     /news/world-us-canada-60439402
# 30  Video 59 secondsPolice clear protesters in Can...                     /news/world-us-canada-60439404
# 31  Video 2 minutes 32 secondsThe women at the for...                               /news/world-60421428
# 32  Video 46 secondsHundreds rescued from Corfu fe...                        /news/world-europe-60433364
# 33               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 34               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 35               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 36              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 37            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 38            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
# 34
# 34
#                                              headline                                               link
# 0   Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 1          How new drugs are finally taming the virus                              /news/health-60390187
# 2        Vaccinated less likely to develop long Covid                              /news/health-60393588
# 3                 Covid deaths in UK continue to fall                              /news/health-60388805
# 4             Lessons in pleasure boost good safe sex                              /news/health-60346008
# 5         Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 6   Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 7          How new drugs are finally taming the virus                              /news/health-60390187
# 8        Vaccinated less likely to develop long Covid                              /news/health-60393588
# 9                 Covid deaths in UK continue to fall                              /news/health-60388805
# 10            Lessons in pleasure boost good safe sex                              /news/health-60346008
# 11        Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 12  Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 13         How new drugs are finally taming the virus                              /news/health-60390187
# 14       Vaccinated less likely to develop long Covid                              /news/health-60393588
# 15                Covid deaths in UK continue to fall                              /news/health-60388805
# 16            Lessons in pleasure boost good safe sex                              /news/health-60346008
# 17        Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 18    How HIV elimination is within Australia's reach                     /news/world-australia-59764592
# 19        The myth of a 'super-charged' immune system                              /news/health-60171592
# 20    Should bad science be censored on social media?                          /news/technology-60036861
# 21  Three ethical issues around pig heart transplants                               /news/world-59951264
# 22  Could a greener asthma inhaler help you breath...                              /news/health-59997297
# 23  Video 2 minutesBeatboxer Shlomo on helping kid...                   /news/uk-england-sussex-60368918
# 24  Video 2 minutes 8 secondsWhat's life like now ...                                  /news/uk-60316361
# 25  Video 2 minutes 24 secondsPregnancy loss podca...                              /news/health-60377339
# 26  Video 2 minutes 1 secondThe gift of life - a n...                 /news/uk-northern-ireland-60352969
# 27  Video 3 minutes 4 secondsMy brother's 34-year ...                              /news/health-60333705
# 28               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
# 34
# 34
#                                              headline                                               link
# 0   Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 1   Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 2         Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 3    Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 4   US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 5                      MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 6   Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 7   Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 8         Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 9    Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 10  US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 11                     MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 12  Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 13  Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 14        Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 15   Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 16  US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 17                     MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 18  'Synaesthesia means I see colours when I hear ...                            /news/newsbeat-60388021
# 19  The actor fighting for the 'right to be forgot...                    /news/world-asia-india-60373229
# 20         Why a 'fake' posh girl enraged South Korea                          /news/world-asia-60384651
# 21     Roblox: The children's game with a sex problem                          /news/technology-60314572
# 22    Eccentric sewage rebels head for the big screen                  /news/entertainment-arts-60349021
# 23  Video 1 minute 30 secondsMeet the man behind t...                                  /news/uk-60445558
# 24  Video 25 secondsFootage shows storm damage to ...                                  /news/uk-60443696
# 25  Video 2 minutesBeatboxer Shlomo on helping kid...                   /news/uk-england-sussex-60368918
# 26  Video 2 minutes 13 secondsThe shipyard that bu...                            /news/uk-wales-60419386
# 27  Video 1 minute 32 seconds'I live my life as a ...    /news/uk-england-coventry-warwickshire-60407626
# 28               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
#                                              headline                                               link
# 0   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 1       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 2   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 3   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 4        Australia says China shone laser at warplane                     /news/world-australia-60446928
# ..                                                ...                                                ...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
#
# [107 rows x 2 columns]

# %% [markdown]
# ## Export the results
#
# And we can export it.

# %%
#And we can export it
allresults.to_csv("scrapeddata.csv")

# %% [markdown]
# Note that the extra 'new line' characters will make it look like the cells are empty in Excel until you double-click in one to see the whole thing.

# %% [markdown]
# ## Improvement 1: adding a delay (throttling)
#
# We can change the scraper so that it pauses between each page. To do this we need the `time` library.

# %%
#Import the time library to use its sleep() function
import time

# %% [markdown]
# We can then use the `sleep()` function from that library, which [stops the code running for a specified number of seconds](https://www.programiz.com/python-programming/time/sleep). So to pause for three seconds it might be written like so:
#
# `time.sleep(3)`
#
# That can be inserted into loop that calls the scraping function (or, if the scraping function scrapes more than one page, you can insert it there to pause between each page):

# %%
#Create a dataframe to store the data we are about to scrape
allresults = pandas.DataFrame()

urllist = ["https://www.bbc.co.uk/news/world","https://www.bbc.co.uk/news/health", "https://www.bbc.co.uk/news/entertainment_and_arts"]

#then loop through them and add to the URL
for i in urllist:
  #scrape that url
  df = scrapepage(i)
  print(df)
  #add the new data frame to the existing data frame
  allresults = allresults.append(df)
  print("waiting 3 seconds before next scrape")
  #Sleep for 3 seconds before looping again
  time.sleep(3)

print(allresults)
# Out:
# 39
# 39
#                                              headline                                               link
# 0   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 1       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 2   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 3   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 4        Australia says China shone laser at warplane                     /news/world-australia-60446928
# 5      Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 6   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 7       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 8   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 9   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 10       Australia says China shone laser at warplane                     /news/world-australia-60446928
# 11     Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 12  Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 13      Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 14  Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 15  Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 16       Australia says China shone laser at warplane                     /news/world-australia-60446928
# 17     Mexican army moves in on drug lord's home town                 /news/world-latin-america-60443514
# 18     US couple plead guilty in nuclear secrets plot                     /news/world-us-canada-60442225
# 19            Epstein ex-associate found dead in jail                        /news/world-europe-60443518
# 20     Ex-soldier given life for French girl's murder                        /news/world-europe-60416617
# 21  US ex-police officer jailed for gun mix-up sho...                     /news/world-us-canada-60436945
# 22  Hopes fade for survivors in Brazil's flood-hit...                 /news/world-latin-america-60426163
# 23  I dance to cope, says Ukrainian amid invasion ...                        /news/world-europe-60446826
# 24  The coach who gave Valieva a 'chilling' reception                    /sport/winter-olympics/60427119
# 25  The Instagram historians chronicling Delhi's past                    /news/world-asia-india-60299136
# 26                   When suspicion gets crowdsourced                     /news/world-us-canada-60091787
# 27             The role of stomachs in electioneering                        /news/world-africa-60023007
# 28  Video 1 minute 6 secondsBiden: I'm convinced P...                     /news/world-us-canada-60440241
# 29  Video 2 minutes 36 seconds'My son's killer nev...                     /news/world-us-canada-60439402
# 30  Video 59 secondsPolice clear protesters in Can...                     /news/world-us-canada-60439404
# 31  Video 2 minutes 32 secondsThe women at the for...                               /news/world-60421428
# 32  Video 46 secondsHundreds rescued from Corfu fe...                        /news/world-europe-60433364
# 33               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 34               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 35               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 36              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 37            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 38            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
# waiting 3 seconds before next scrape
# 34
# 34
#                                              headline                                               link
# 0   Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 1          How new drugs are finally taming the virus                              /news/health-60390187
# 2        Vaccinated less likely to develop long Covid                              /news/health-60393588
# 3                 Covid deaths in UK continue to fall                              /news/health-60388805
# 4             Lessons in pleasure boost good safe sex                              /news/health-60346008
# 5         Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 6   Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 7          How new drugs are finally taming the virus                              /news/health-60390187
# 8        Vaccinated less likely to develop long Covid                              /news/health-60393588
# 9                 Covid deaths in UK continue to fall                              /news/health-60388805
# 10            Lessons in pleasure boost good safe sex                              /news/health-60346008
# 11        Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 12  Two glasses of wine enough to hit daily sugar ...                              /news/health-60390314
# 13         How new drugs are finally taming the virus                              /news/health-60390187
# 14       Vaccinated less likely to develop long Covid                              /news/health-60393588
# 15                Covid deaths in UK continue to fall                              /news/health-60388805
# 16            Lessons in pleasure boost good safe sex                              /news/health-60346008
# 17        Woman awaiting surgery to remove 8kg tumour          /news/uk-england-nottinghamshire-60375695
# 18    How HIV elimination is within Australia's reach                     /news/world-australia-59764592
# 19        The myth of a 'super-charged' immune system                              /news/health-60171592
# 20    Should bad science be censored on social media?                          /news/technology-60036861
# 21  Three ethical issues around pig heart transplants                               /news/world-59951264
# 22  Could a greener asthma inhaler help you breath...                              /news/health-59997297
# 23  Video 2 minutesBeatboxer Shlomo on helping kid...                   /news/uk-england-sussex-60368918
# 24  Video 2 minutes 8 secondsWhat's life like now ...                                  /news/uk-60316361
# 25  Video 2 minutes 24 secondsPregnancy loss podca...                              /news/health-60377339
# 26  Video 2 minutes 1 secondThe gift of life - a n...                 /news/uk-northern-ireland-60352969
# 27  Video 3 minutes 4 secondsMy brother's 34-year ...                              /news/health-60333705
# 28               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
# waiting 3 seconds before next scrape
# 34
# 34
#                                              headline                                               link
# 0   Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 1   Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 2         Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 3    Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 4   US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 5                      MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 6   Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 7   Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 8         Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 9    Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 10  US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 11                     MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 12  Big Jet TV turns plane-watching into a phenomenon                  /news/entertainment-arts-60434909
# 13  Brad battles Angelina over vineyard where they...                  /news/entertainment-arts-60430014
# 14        Dizzee Rascal 'pushed ex-fiancee to ground'                   /news/uk-england-london-60432874
# 15   Viola Davis seen as Michelle Obama in TV trailer                  /news/entertainment-arts-60430016
# 16  US TV star sues Disney over Covid 'discriminat...                  /news/entertainment-arts-60431480
# 17                     MasterChef moves to Birmingham               /news/uk-england-birmingham-60431498
# 18  'Synaesthesia means I see colours when I hear ...                            /news/newsbeat-60388021
# 19  The actor fighting for the 'right to be forgot...                    /news/world-asia-india-60373229
# 20         Why a 'fake' posh girl enraged South Korea                          /news/world-asia-60384651
# 21     Roblox: The children's game with a sex problem                          /news/technology-60314572
# 22    Eccentric sewage rebels head for the big screen                  /news/entertainment-arts-60349021
# 23  Video 1 minute 30 secondsMeet the man behind t...                                  /news/uk-60445558
# 24  Video 25 secondsFootage shows storm damage to ...                                  /news/uk-60443696
# 25  Video 2 minutesBeatboxer Shlomo on helping kid...                   /news/uk-england-sussex-60368918
# 26  Video 2 minutes 13 secondsThe shipyard that bu...                            /news/uk-wales-60419386
# 27  Video 1 minute 32 seconds'I live my life as a ...    /news/uk-england-coventry-warwickshire-60407626
# 28               The workers 'going to the dark side'  https://www.bbc.com/worklife/article/20220215-...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
# waiting 3 seconds before next scrape
#                                              headline                                               link
# 0   Video 1 minute 7 secondsUS warns of consequenc...                               /news/world-60445560
# 1       Ottawa police close in on vaccine protest hub                     /news/world-us-canada-60420469
# 2   Search for 12 missing after ferry blaze continues                        /news/world-europe-60443517
# 3   Malian soldiers killed after France announces ...                        /news/world-africa-60444777
# 4        Australia says China shone laser at warplane                     /news/world-australia-60446928
# ..                                                ...                                                ...
# 29               A ski town stuck in the wrong nation  https://www.bbc.com/travel/article/20220214-ju...
# 30               The man known as the anti-James Bond  https://www.bbc.com/culture/article/20220217-t...
# 31              The animal 'sixth sense' for disaster  https://www.bbc.com/future/article/20220211-th...
# 32            Why people believe in the soulmate myth  https://www.bbc.com/worklife/article/20220204-...
# 33            Is this America's next best restaurant?  https://www.bbc.com/travel/article/20220215-is...
#
# [107 rows x 2 columns]
