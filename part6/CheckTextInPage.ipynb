# %% [markdown]
# # How to use Python to tell if a webpage contains a word (string) or not
#
# How can you get a `True`/`False` result telling you if a page contains a particular string?
#
# Let's import some libraries to scrape a page first...

# %%
#import our libraries
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Then scrape a page we can deal with...

# %%
#store the url to run our scraper on
testurl = "https://www.thebureauinvestigates.com/"
#fetch the page at that url
page = requests.get(testurl)
#test that it's worked - Response 200 means it's not broken
page
# Out:
# <Response [200]>

# %%
#check the content
page.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n\t<head>\n    <meta charset="UTF-8">\n\n    \n    <title>The Bureau of Investigative Journalism (en-GB)</title>\n    <meta name="description" content="Home of the Bureau of Investigative Journalism, an independent, not-for-profit media organisation that holds power to account." />\n    \n    <link rel="home" href="https://www.thebureauinvestigates.com/" />\n\n    \n    \n        <meta name="twitter:card" content="summary_large_image">\n    <meta name="twitter:site" content="@TBIJ">\n    <meta name="twitter:creator" content="@TBIJ">\n    <meta name="twitter:title" content="The Bureau of Investigative Journalism (en-GB)">\n    <meta name="twitter:description" content="Home of the Bureau of Investigative Journalism, an independent, not-for-profit media organisation that holds power to account.">\n    <meta name="twitter:image:src" content="https://d3cocnzdt9u6c9.cloudfront....">\n\n    <meta property="og:type" content="article">\n    <meta property="og:title" content="The Bureau of Investigative Journalism (en-GB)">\n    <meta property="og:description" content="Home of the Bureau of Investigative Journalism, an independent, not-for-profit media organisation that holds power to account.">\n    <meta property="og:url" content="https://www.thebureauinvestigates.com/">\n    <meta property="og:site_name" content="The Bureau of Investigative Journalism (en-GB)">\n    <meta property="og:image" content="https://d3cocnzdt9u6c9.cloudfront....">\n\n\n        \n            \n        <script type="application/ld+json">\n\n            {"@context":"http:\\/\\/schema.org","@type":"Organization","legalName":"The Bureau of Investigative Journalism (en-GB)","url":"https:\\/\\/www.thebureauinvestigates.com\\/","logo":"https:\\/\\/www.thebureauinvestigates.com\\/assets\\/img\\/tbij-logo-large@2x.png","sameAs":["https:\\/\\/twitter.com\\/TBIJ","https:\\/\\/www.facebook.com\\/thebureauinvestigates","https:\\/\\/www.linkedin.com\\/company\\/the-bureau-of-investigative-journalism?trk=company_name"]}\n        \n        </script>\n\n            \n        <script type="application/ld+json">\n\n            {"@context":"http:\\/\\/schema.org","@type":"WebSite","name":"The Bureau of Investigative Journalism (en-GB)","url":"https:\\/\\/www.thebureauinvestigates.com\\/","potentialAction":{"@type":"SearchAction","target":"https:\\/\\/www.thebureauinvestigates.com\\/search?q={search_term}","query-input":"required name=search_term"}}\n        \n        </script>\n\n    \n\n    <meta name="viewport" content="width=device-width, minimum-scale=1.0">\n    <meta name="format-detection" content="telephone=no">\n    <link rel="stylesheet" href="/assets/css/main.1631957150.css">\n\n    <link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png?v=PYEwjPlayy">\n    <link rel="icon" type="image/png" href="/favicon-32x32.png?v=PYEwjPlayy" sizes="32x32">\n    <link rel="icon" type="image/png" href="/favicon-16x16.png?v=PYEwjPlayy" sizes="16x16">\n    <link rel="manifest" href="/manifest.json?v=PYEwjPlayy">\n    <link rel="mask-icon" href="/safari-pinned-tab.svg?v=PYEwjPlayy" color="#5bbad5">\n    <link rel="shortcut icon" href="/favicon.ico?v=PYEwjPlayy">\n    <meta name="theme-color" content="#ffffff">\n\n    <!--[if lt IE 9]>\n        <script src="/assets/js/html5-printshiv.js"></script>\n    <![endif]-->\n\n    <!-- Facebook Pixel Code -->\n<script>\n!function(f,b,e,v,n,t,s)\n{if(f.fbq)return;n=f.fbq=function(){n.callMethod?\nn.callMethod.apply(n,arguments):n.queue.push(arguments)};\nif(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version=\'2.0\';\nn.queue=[];t=b.createElement(e);t.async=!0;\nt.src=v;s=b.getElementsByTagName(e)[0];\ns.parentNode.insertBefore(t,s)}(window,document,\'script\',\n\'https://connect.facebook.net/en_US/fbevents.js\');\n      fbq(\'consent\', \'revoke\');\n  \n  fbq(\'init\', \'266302737239845\');\n  fbq(\'track\', \'PageView\');\n</script>\n<noscript>\n <img height="1" width="1"\nsrc="https://www.face ...

# %% [markdown]
# ## Convert your bytes object to a string
#
# If we try to test if the string 'Bureau' is in the page, we will get an error with this code:

# %%
#This will give you an error because it's not a string object - it's a 'bytes'
"Bureau" in page.content
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-50ecfd44f74f> in <module>()
# ----> 1 "Bureau" in page.content
#
# TypeError: a bytes-like object is required, not 'str'

# %% [markdown]
# [Google the error!](https://stackoverflow.com/questions/33054527/typeerror-a-bytes-like-object-is-required-not-str-when-writing-to-a-file-in): "You opened the file in binary mode" (that's the `b` at the start when it's printed out).
#
# So you need to convert it to a string using the `str()` function like this:

# %%
#Convert page.content to a string by using the str() function first
"Bureau" in str(page.content)
# Out:
# True

# %% [markdown]
# ## Searching a 'soup' object
#
# If we try the same approach on a BeautifulSoup object, it won't work.

# %%
#turn into soup
soup = BeautifulSoup(page.content)

# %%
"Bureau" in soup
# Out:
# False

# %% [markdown]
# Instead you need to drill down into particular parts.
#
# The simplest way to do this is to grab all matches for the `<html>` tag. This tag contains the entire page.
#
# You need to remember that `.select()` will *always return a list* even if, as in this case, there's only one match, so you still need to select the *first match* when testing if your string is in it.

# %%
#grab all the html tags (there's only one)
body = soup.select('html')
#check if the text contents of the first (and only) html tag contains your string.
"Bureau" in body[0].get_text()
# Out:
# True

# %%
#store in a variable
bodytext = body[0].get_text()
#show the first 100 characters
bodytext[0:100]
# Out:
# '\n\n\nThe Bureau of Investigative Journalism (en-GB)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            {"@context":"http:\\/\\/'

# %%
#plit on the word 'Bureau'
bureausplit = bodytext.split("Bureau")
#show how many items are created
len(bureausplit)
# Out:
# 22

# %% [markdown]
# We can print the first item to show you what comes before the first match of 'Bureau'.

# %%
bureausplit[0]
# Out:
# '\n\n\nThe '

# %% [markdown]
# And the second item which comes after it. Notice that the word 'Bureau' has been removed when you use `.split()`.

# %%
bureausplit[1]
# Out:
# ' of Investigative Journalism (en-GB)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n            {"@context":"http:\\/\\/schema.org","@type":"Organization","legalName":"The '

# %% [markdown]
# So to see the context around the word you need to print the first (or last) few characters that came after (or before) it.
#
# We've picked 30 characters below but this is after a process of trial and error, trying different numbers to see what we get and whether we want more or less.

# %%
#for each item we get when we spllit
for i in bureausplit:
  #print the first 30 characters
  print(i[0:30])
# Out:
# The
#  of Investigative Journalism (
#  of Investigative Journalism (
#  of Investigative Journalism (
#  Website
#
#
# The
#  on Facebook
#
#
# The
#  on Twitter
#
#
#
#
#
#
#
#
#
#
#
#
# Storie
#  Global
#
# Smoke Screen
# Coronavi
#  Local
#
# Stories
# About the Proj
#
# The Trust for TBIJ
#
#
#
# Got a S
#
# How to Talk to a Journalist
#
#
#
#
# Donate now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# The Housing Crisis
#
# B
#  has found hundreds of mortgag
#  co-publishes its stories with
#  announces Rozina Breen as new
#
# Investigative journalism is v
#  newsletter
# Subscribe to the
#  newsletter, and hear when our
#
# How to Talk to a Journalist
#
#
#  of Investigative Journalism
# P
#  Local

# %% [markdown]
# We can add "Bureau" and exclude the first item (because it's *before* "Bureau") like this:

# %%
#for each item we get when we spllit
for i in bureausplit[1:]:
  #print the first 30 characters
  print("Bureau"+i[0:30])
# Out:
# Bureau of Investigative Journalism (
# Bureau of Investigative Journalism (
# Bureau of Investigative Journalism (
# Bureau Website
#
#
# The
# Bureau on Facebook
#
#
# The
# Bureau on Twitter
#
#
#
#
#
#
#
#
#
#
#
#
# Storie
# Bureau Global
#
# Smoke Screen
# Coronavi
# Bureau Local
#
# Stories
# About the Proj
# Bureau
# The Trust for TBIJ
#
#
#
# Got a S
# Bureau
# How to Talk to a Journalist
#
#
# Bureau
#
# Donate now
#
#
#
#
#
#
# Bureau
#
#
#
#
#
#
#
#
# The Housing Crisis
#
# B
# Bureau has found hundreds of mortgag
# Bureau co-publishes its stories with
# Bureau announces Rozina Breen as new
# Bureau
# Investigative journalism is v
# Bureau newsletter
# Subscribe to the
# Bureau newsletter, and hear when our
# Bureau
# How to Talk to a Journalist
#
#
# Bureau of Investigative Journalism
# P
# Bureau Local

# %% [markdown]
# ## Trying this on a Russian page
#
# The `page.content`-based approach above doesn't seem to work on a particular page.

# %%
#fetch a page
page = requests.get("https://utro.ru/news/ukraine/2022/03/07/1507101.shtml")
#show the content
page.content
# Out:
# b'\n<!DOCTYPE html>\n<html class="no-js" lang="">\n\n<head>\n\n\n\n<title>\xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\xd0\xb8\xd0\xbd\xd0\xb0 \xd0\xbf\xd0\xbe\xd0\xbe\xd0\xb1\xd0\xb5\xd1\x89\xd0\xb0\xd0\xbb\xd0\xb0 \xd0\xa0\xd0\xbe\xd1\x81\xd1\x81\xd0\xb8\xd0\xb8 \xd1\x81\xd1\x8e\xd1\x80\xd0\xbf\xd1\x80\xd0\xb8\xd0\xb7 - \xd0\xb3\xd0\xbb\xd0\xb0\xd0\xb2\xd0\xb0 \xd0\x9c\xd0\xb8\xd0\xbd\xd0\xbe\xd0\xb1\xd0\xbe\xd1\x80\xd0\xbe\xd0\xbd\xd1\x8b \xd0\xa0\xd0\xb5\xd0\xb7\xd0\xbd\xd0\xb8\xd0\xba \xd1\x81\xd0\xbe\xd0\xbe\xd0\xb1\xd1\x89\xd0\xb8\xd0\xbb \xd0\xbe \xd0\xbf\xd0\xbe\xd1\x81\xd1\x82\xd0\xb0\xd0\xb2\xd0\xba\xd0\xb0\xd1\x85 \xd0\xbe\xd1\x80\xd1\x83\xd0\xb6\xd0\xb8\xd1\x8f, \xd0\xbd\xd0\xbe\xd0\xb2\xd0\xbe\xd1\x81\xd1\x82\xd0\xb8 \xd0\xb4\xd0\xbd\xd1\x8f :: \xd0\x9d\xd0\xbe\xd0\xb2\xd0\xbe\xd1\x81\xd1\x82\xd0\xb8 \xd0\xa3\xd0\xba\xd1\x80\xd0\xb0\x
cut icon" type="image/x-icon" href="/static/img/favicon.ico" />\n\n<meta name="apple-itunes-app" content="app-id=482911429">\n\n<link rel="manifest" href="/static/manifest.json">\n\n<script type="text/javascript" src="/static/js/jquery.min.js"></script>\n<script type="text/javascript" src="/static/js/jquery.cookie.js"></script>\n\n\n<link rel="stylesheet" type="text/css" href="/static/css/font/font.css">\n<link rel="stylesheet" type="text/cs ...

# %%
#Check if a string is in it that we know should be
"news" in str(soup.content)
# Out:
# False

# %% [markdown]
# So let's try the soup approach.

# %%
#convert to a soup object
soup = BeautifulSoup(page.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="">
# <head>
# <title>Украина пообещала России сюрприз - глава Минобороны Резник сообщил о поставках оружия, новости дня :: Новости Украины</title>
# <meta content="text/xml; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="index,follow" name="Robots">
# <meta content="последние новости, лента новостей, новости сегодня, новости России и мира, утро ру" name="keywords"/>
# <meta content="В Незалежной похвалились поставками оружия" name="description"/>
# <meta content="article" property="og:type"/>
# <meta content="Украина пообещала России сюрприз - глава Минобороны Резник сообщил о поставках оружия, новости дня" property="og:title"/>
# <meta content="В Незалежной похвалились поставками оружия" property="og:description"/>
# <meta content="https://utro.ru/news/ukraine/2022/03/07/1507101.shtml" property="og:url"/>
# <meta content="https://pics.utro.ru/utro_photos/2022/03/07/1507101big.jpg" property="og:image"/>
# <link href="https://utro.ru/news/ukraine/2022/03/07/1507101.shtml" rel="canonical"/>
# <meta content="i7oyF_4bPu9-QGjoWgjAy3iENwP-8XDv4Qpme8bAVCw" name="google-site-verification"/>
# <link href="/static/img/favicon.ico" rel="shortcut icon" type="image/x-icon">
# <meta content="app-id=482911429" name="apple-itunes-app"/>
# <link href="/static/manifest.json" rel="manifest"/>
# <script src="/static/js/jquery.min.js" type="text/javascript"></script>
# <script src="/static/js/jquery.cookie.js" type="text/javascript"></script>
# <link href="/static/css/font/font.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/font/fontello.css?v2" rel="stylesheet" type="text/css"/>
# <link href="/static/css/normalize.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/newmain.css?v12" rel="stylesheet" type="text/css"/>
# <link href="/static/css/fix.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/drop-navi.css?v2" rel="stylesheet" type="text/css"/>
# <script src="/static/js/vendor/modernizr-2.8.3.min.js" type="text/javascript"></script>
# <link href="https://utro.ru/amp/news/ukraine/2022/03/07/1507101.shtml" rel="amphtml"/>
# <link href="https://mc.yandex.ru" rel="dns-prefetch"/>
# <link href="https://yastatic.net" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://static.videonow.ru" rel="dns-prefetch"/>
# <noindex>
# <!-- google analytics -->
# <script type="text/javascript">
# 			function recordOutboundLink(link, category, action) {
# 				try {
# 					_gat._createTracker("UA-22073661-1","myT");
# 					_gat._getTrackerByName("myT")._trackEvent(category, action);
# 				} catch(err) {}
# 				setTimeout( function(){
# 					document.location = link.href
# 				}, 100 );
# 			}
# 		</script>
# <script type="text/javascript">
# 		  var _gaq = _gaq || [];
# 		  _gaq.push(
# 				['_setAccount', 'UA-22073661-1']
# 			  , ['_setDomainName', 'utro.ru']
# 			  , ['_trackPageview']
# 			  // Счетчик Медиа-1
# 			  ,['RBC._setAccount', 'UA-8487723-7']
# 			  ,['RBC._setDomainName', 'rbc.ru']
# 			  ,['RBC._setAllowLinker', true]
# 			  ,['RBC._trackPageview']);
# 		  (function() {
# 			var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
# 			ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
# 			var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
# 		  })();
# 		</script>
# <!-- /google analytics -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-FB1GYCCPFP"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'G-FB1GYCCPFP');
# </script>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
# (function(m,e,t,r,i,k,a){m[i]=m[i]||function()
#
# {(m[i].a=m[i].a||[]).push(arguments)}
# ;
# m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
# (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
# ym(42382979, "init",
#
# { clickmap:true, trackLinks:true, accurateTrackBounce:true, webvisor:true }
# );
# </script>
# <noscript><div><img alt="" src="https://mc.yandex.ru/watch/42382979" style="position:absolute; left:-9999px;"/></div></noscript>
# <!-- /Yandex.Metrika counter -->
# <script type="text/javascript">
# 				/* CONFIGURATION START */
# 				var _ain = {
# 						id: "1401",
# 						url: "",
# 						postid: "",
# 						maincontent: "",
# 						title: "",
# 						pubdate: "",
# 						authors: "",
# 						sections: "",
# 						tags: "",
# 						comments: ""
# 				};
# 				/* CONFIGURATION END */
# 				(function (d, s) {
# 				var sf = d.createElement(s); sf.type = 'text/javascript'; sf.async = true;
# 				sf.src = (('https:' == d.location.protocol) ? 'https://d7d3cf2e81d293050033-3dfc0615b0fd7b49143049256703bfce.ssl.cf1.rackcdn.com' : 'http://t.contentinsights.com')+'/stf.js';
# 				var t = d.getElementsByTagName(s)[0]; t.parentNode.insertBefore(sf, t);
# 				})(document, 'script');
# 			</script>
# <!-- Rating Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3195882", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3195882;js=na" style="border:0;position:absolute;left:-9999px;"/>
# </div></noscript>
# <!-- //Rating Mail.ru counter -->
# <script async="" data-uid="3e9a7dfc7806437a0bdc84da516da879" id="my-widget-script" src="https://likemore-go.imgsmail.ru/widget.js"></script>
# <!-- hb setup utro 15.02.22 desktop //-->
# <link href="//static.criteo.net" rel="dns-prefetch"/>
# <link href="//bidder.criteo.com" rel="dns-prefetch"/>
# <script src="https://static.criteo.net/js/ld/publishertag.js"></script>
# <link crossorigin="" href="https://ads.betweendigital.com" rel="preconnect"/>
# <script src="https://yandex.ru/ads/system/header-bidding.js"></script>
# <script>
# var adfoxBiddersMap = {
#   "criteo": "826875",
#   "myTarget": "826876",
#   "betweenDigital": "826877",
#   "rtbhouse": "1136528",
#   "buzzoola": "1809906",
#   "adfox_roden-media": "1822852"
# };
#
# var adUnits = [
#   {
#     "code": "adfox_153263471838398691",      // top 1000x250
#     "sizes": [
#       [
#         970,
#         250
#       ],
#       [
#         1000,
#         120
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1290186"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "2534783"
#         }
#       },
#       {
#         "bidder": "adfox_roden-media",
#         "params": {
#           "p1": "cskta",
#           "p2": "hfln",
#           "puid1": "",
#           "puid2": "",
#           "puid3": "",
#           "puid4": "",
#           "puid5": "",
#           "puid6": ""
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_153263525493889471",     // 300х600 middle right
#     "sizes": [
#       [
#         300,
#         600
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1290180"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "246629"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "2534785"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "hcZkONVLotgjkBJnGmyH"
#         }
#       },
#       {
#         "bidder": "buzzoola",
#         "params": {
#           "placementId": "1227832"
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_15326354373794136",	    // 300х400
#     "codeType": "combo",
#     "sizes": [
#       [
#         240,
#         400
#       ],
#       [
#         300,
#         300
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1514997"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "774904"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "3871385"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "nABU7G6Rppxwih52kNfz"
#         }
#       },
#       {
#         "bidder": "buzzoola",
#         "params": {
#           "placementId": "1227163"
#         }
#       },
#       {
#         "bidder": "adfox_roden-media",
#         "params": {
#           "p1": "csktb",
#           "p2": "emwl",
#           "puid1": "",
#           "puid2": "",
#           "puid3": "",
#           "puid4": "",
#           "puid5": "",
#           "puid6": ""
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_153263550155581761",     // 300х250
#     "sizes": [
#       [
#         300,
#         250
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1514998"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "774906"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "3871386"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "MPbGNYmmGWpFB8xtSotj"
#         }
#       },
#       {
#         "bidder": "buzzoola",
#         "params": {
#           "placementId": "1227831"
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_153263563631543965",     // 970x250 middle
#     "codeType": "combo",
#     "sizes": [
#       [
#         970,
#         250
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1290179"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "246919"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "2534784"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "XxGPGKovDOV0ZG5KAOpC"
#         }
#       },
#       {
#         "bidder": "buzzoola",
#         "params": {
#           "placementId": "1227833"
#         }
#       },
#       {
#         "bidder": "adfox_roden-media",
#         "params": {
#           "p1": "csktc",
#           "p2": "etsw",
#           "puid1": "",
#           "puid2": "",
#           "puid3": "",
#           "puid4": "",
#           "puid5": "",
#           "puid6": ""
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_153263570491382807",     // 970х250 bottom
#     "sizes": [
#       [
#         970,
#         250
#       ]
#     ],
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1514996"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "774902"
#         }
#       },
#       {
#         "bidder": "betweenDigital",
#         "params": {
#           "placementId": "3871384"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "Wn6t5gCYmfMpeMGchTgq"
#         }
#       }
#     ]
#   },
#   {
#     "code": "adfox_153263509370942323",     // 240х400 right before pic
#     "bids": [
#       {
#         "bidder": "criteo",
#         "params": {
#           "placementId": "1297993"
#         }
#       },
#       {
#         "bidder": "myTarget",
#         "params": {
#           "placementId": "246949"
#         }
#       },
#       {
#         "bidder": "rtbhouse",
#         "params": {
#           "placementId": "AFdv3rjFRhOABA5zfdAH"
#         }
#       }
#     ]
#   }
# ];
#
# var userTimeout = 999;
#
# window.YaHeaderBiddingSettings = {
#   biddersMap: adfoxBiddersMap,
#   adUnits: adUnits,
#   timeout: userTimeout
# };
# </script>
# <script>
#     window.Criteo = window.Criteo || {};
#     window.Criteo.events = window.Criteo.events || [];
# </script>
# <script>window.yaContextCb = window.yaContextCb || []</script>
# <script async="" data-relap-token="oNigYORgE2yRYJGU" src="https://relap.io/v7/relap.js" type="text/javascript"></script>
# <script type="text/javascript">
#
#    var moevideo = moevideo || {};
#    moevideo.queue = moevideo.queue || [];
#     (function() {
#      var mvads = document.createElement("script");
#      mvads.async = true;
#      mvads.type = "text/javascript";
#      var useSSL = "https:" == document.location.protocol;
#      mvads.src = (useSSL ? "https:" : "http:") + "//moevideo.biz/embed/js/mvpt.min.js";
#      var node =document.getElementsByTagName("head")[0];
#      node.appendChild(mvads, node);
#     })();
# </script>
# </noindex>
# <script async="" src="/static/js/push.js" type="text/javascript"></script>
# <script async="" src="/static/js/adfox.custom.min.js" type="text/javascript"></script>
# <script async="" src="/static/js/ScrollMagic.min.js" type="text/javascript"></script>
# </link></meta></head>
# <body>
# <script src="/static/js/art-blocks.js" type="text/javascript"></script>
# <!--link rel="stylesheet" type="text/css" media="all" href=/static/lightbox/css/jquery.lightbox-0.5.css>
# 	<script type="text/javascript" src=/static/lightbox/js/jquery.lightbox-0.5.min.js></script-->
# <link href="/static/lightbox2/dist/css/lightbox.css" media="all" rel="stylesheet" type="text/css"/>
# <script src="/static/js/subscribe.js" type="text/javascript"></script>
# <script src="/static/lightbox2/dist/js/lightbox.js" type="text/javascript"></script>
# <div class="mask"></div>
# <div class="layout-width" id="wrap">
# <div class="adv__brend">
# <div id="adfox_153494529588693006"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
# 		ownerId: 275069,
# 		containerId: 'adfox_153494529588693006',
# 		onLoad: function(data) {
# 			$("#wrap").addClass("brendpage");
# 		},
# 		params:
# 		{ pp: 'g', ps: 'cxhg', p2: 'gazz' }
# 	});
# });
# </script>
# </div>
# <header class="header" id="header-bar">
# <a class="header__logo" href="/">
# <img alt="" src="/static/img/logo.png"/>
# </a>
# <nav>
# <ul class="primary-nav">
# <li class="active"><a class="highlight" href="/online/ukraine.shtml">Новости Украины</a></li>
# <li class="active">
# <a href="/ukraine.shtml" style="color: red">Спецоперация на Украине</a>
# </li>
# <li>
# <a href="/politics.shtml">Политика</a>
# </li>
# <li>
# <a href="/online/pensii.shtml">Пенсии</a>
# </li>
# <li>
# <a href="/horoscope.shtml">Гороскоп</a>
# </li>
# <li>
# <a href="/showbiz.shtml">Шоу-бизнес</a>
# </li>
# <li>
# <a href="/pr.shtml">Пресс-релизы</a>
# </li>
# </ul>
# </nav>
# <button class="toggle-drop-navi">
# <i></i>
# <i></i>
# <i></i>
# </button>
# <div class="header__search">
# <form action="/search/">
# <input class="header__search-input" name="q" placeholder="Поиск по сайту" type="text"/>
# </form>
# <button class="toggle-search">
# <i class="icon-search"></i>
# </button>
# </div>
# <ul class="header__currency">
# </ul>
# <div class="header__drop-navi">
# <div class="_inner">
# <ul class="menu">
# <li class="menu__item">
# <a href="/coronavirus.shtml">КОРОНАВИРУС</a>
# </li>
# <li class="menu__item">
# <a href="/life.shtml">ЖИЗНЬ</a>
# </li>
# <li class="menu__item">
# <a href="/recepty.shtml">РЕЦЕПТЫ</a>
# </li>
# <li class="menu__item">
# <a href="/online/primety.shtml">ПРИМЕТЫ</a>
# </li>
# <li class="menu__item">
# <a href="/online/crimean.shtml">НОВОСТИ КРЫМА</a>
# </li>
# <li class="menu__item">
# <a href="/economics.shtml">ЭКОНОМИКА</a>
# </li>
# <li class="menu__item">
# <a href="/accidents.shtml">ПРОИСШЕСТВИЯ</a>
# </li>
# <li class="menu__item">
# <a href="/online/ogorod.shtml">САД И ОГОРОД</a>
# </li>
# </ul>
# </div>
# </div>
# </header>
# <div class="head__adv" id="GB_advert_1">
# <!--AdFox START-->
# <!--utroru15-->
# <!--Площадка: utro.ru десктоп / * / *-->
# <!--Тип баннера: desktop 2. Перетяжка верхняя-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153263471838398691"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
#         ownerId: 275069,
#         containerId: 'adfox_153263471838398691',
#         params: {
#             pp: 'g',
#             ps: 'cxhg',
#             p2: 'gatj'
#         }
#     });
# });
# </script>
# </div>
# <div style="width:100%; height:90px; background:#fff; display: none;">
# <div class="block__title-adv" style="display: none;">Реклама</div>
# </div>
# <main>
# <div id="content">
# <div class="layout-two-column">
# <div class="layout-two-column__main">
# <div class="news">
# <h1 class="news__title">Украинский министр обороны пообещал России "сюрприз"</h1>
# <figure class="news__media">
# <picture>
# <source srcset="https://pics.utro.ru/utro_photos/2022/03/07/1507101.jpg.webp" type="image/webp"/>
# <img alt='Украинский министр обороны пообещал России "сюрприз"' class="lazyload" height="470" src="https://pics.utro.ru/utro_photos/2022/03/07/1507101.jpg" title='Украинский министр обороны пообещал России "сюрприз"' width="840"/>
# </picture>
# <figcaption>Фото: Dominika Zarzycka/Keystone Press Agency/www.globallookpress.com</figcaption>
# </figure>
# <div class="news__social" style="">
#
# 							прочитано 1685 раз
#
# 			        <a href="https://zen.yandex.ru/ytro.ru" target="_blank"><i class="icon-yandex"></i></a>
# <a href="https://news.google.com/publications/CAAiEOF7XMpY3eSH2Jkm8AEzhb0qFAgKIhDhe1zKWN3kh9iZJvABM4W9?hl=ru&amp;gl=RU&amp;ceid=RU%3Aru" target="_blank"><i class="icon-google"></i></a>
# </div>
# <div class="fly-social-wrap">
# <div class="fly-social">
# <script type="text/javascript">(function() {
# 			if (window.pluso)if (typeof window.pluso.start == "function") return;
# 			if (window.ifpluso==undefined) { window.ifpluso = 1;
# 			var d = document, s = d.createElement('script'), g = 'getElementsByTagName';
# 			s.type = 'text/javascript'; s.charset='UTF-8'; s.async = true;
# 			s.src = ('https:' == window.location.protocol ? 'https' : 'http') + '://share.pluso.ru/pluso-like.js';
# 			var h=d[g]('body')[0];
# 			h.appendChild(s);
# 			}})();</script>
# <div class="pluso" data-background="transparent" data-options="medium,square,line,vertical,counter,theme=06" data-services="vkontakte,odnoklassniki,facebook,twitter,email"></div>
# </div>
# </div>
# <div class="news__short-link"><span class="news__short-link-title">продолжение</span><a href="/news/ukraine/2022/03/07/1507105.shtml">Проболтались: американские СМИ подставили Зеленского</a></div>
# <div class="news__lead">
#                 В Незалежной похвалились поставками оружия
#             </div>
# <div class="js-mediator-article io-article-bod" data-io-article-url="https://utro.ru/news/ukraine/2022/03/07/1507101.shtml"><p>Глава украинского Минобороны Алексей Резников выступил с
# заявлением. Он сообщил, что Киев добился значительного прогресса в поставках
# оружия в страну. При этом подробности он раскрывать отказался, сославшись на
# то, что это "деликатный момент". И пообещал удивить Москву.<br/></p><p class="article__quote">"Пусть
# врага ждет сюрприз", – заявил Резников.</p><p>Некоторые
# детали глава военного ведомства все же выдал. Он сообщил, что за последние дни
# доставлено, в процессе доставки либо законтрактовано более 50 тысяч касок и
# бронежилетов. Он добавил, что Украина якобы "перехватывает" у поставщиков
# готовое обмундирование для натовских военных. Украинская сторона решила одеть
# своих военнослужащих "в разное", отметил Резников.</p><p>О начале
# военной спецоперации на Украине российский лидер Владимир Путин объявил 24
# февраля. Позже он сказал, что это решение было тяжелым. Главной целью России
# является демилитаризация Украины, подчеркнул президент.</p></div>
# <div class="stop-fly"></div>
# <div class="clearfix"></div>
# <div class="news__meta">
# <time class="news__date" datetime="2022-03-07" pubdate="">11:00, 07.03.2022</time></div></div></div></div></div></main></div></body></html>
# <span class="article_source">Источник: <a href="https://ria.ru/20220307/ukraina-1777009831.html" rel="noopener noreferrer" target="_blank">РИА Новости</a>  ✓ Надежный источник</span>
# <div class="news-center__top-author io-author">
# <i></i>
# <a href="/author/%D0%9A%D1%80%D0%B8%D1%81%D1%82%D0%B8%D0%BD%D0%B0%20%D0%A7%D0%95%D0%A0%D0%9D%D0%98%D0%9A%D0%9E%D0%92%D0%90/">Кристина ЧЕРНИКОВА</a>
# </div>
#
# <div class="news__ads">
# </div>
# <div class="news__partners-horizontal">
# <div class="news-block__title">новости партнеров</div>
# <div id="infox_18814"></div><script type="text/javascript">
# (function(w, d, n, s, t) {
# w[n] = w[n] || [];
# w[n].push(function()
#
# { INFOX18814.renderTo("infox_18814"); }
# );
# t = d.getElementsByTagName("script")[0];
# s = d.createElement("script");
# s.type = "text/javascript";
# s.src = "//rb.infox.sg/infox/18814";
# s.async = true;
# t.parentNode.insertBefore(s, t);
# })(this, this.document, "infoxContextAsyncCallbacks18814");
# </script>
# <div class="pulse-widget" data-sid="partners_widget_ytroru"></div> <script async="" src="https://static.pulse.mail.ru/pulse-widget.js"> </script>
# <div class="js-relap-anchor" data-relap-id="FukWI-IiAfMJnx8f"></div>
# <div id="containerId19325"></div>
# <script>
# (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push(function() {
#     	$.getScript("https://news.gnezdo.ru/loader.js", function() {
# (function(w, d, c, s, t){
# w[c] = w[c] || [];
# w[c].push(function(){
# gnezdo.create(
#
# { tizerId: 19325, containerId: 'containerId19325' }
# );
# });
# })(window, document, 'gnezdoAsyncCallbacks');
#     	});
#     });
# })(this, "utroCallbacks");
# </script>
# </div>
# <div class="news-section">
# <div class="title">По теме</div>
# <ul class="news-section__list">
# <li>
# <a href="/news/ukraine/2022/03/07/1505982.shtml">Россия проводит спецоперацию в Донбассе. Онлайн</a>
# </li>
# <li>
# <a href="/news/ukraine/2022/03/05/1507038.shtml">Ядерные силы РФ перевели на особый режим - Путин</a>
# </li>
# <li>
# <a href="/persons/putin.shtml">Владимир  Владимирович Путин </a>
# </li>
# </ul>
# </div>
# <div class="news__blocks-news">
# <div class="_row">
# <div class="news-center__item _item-shadow">
# <div class="news-center__top" data-vr-contentbox="Position 1" data-vr-contentbox-url="https://utro.ru/news/politics/2022/03/05/1506977.shtml">
# <a href="/news/politics/2022/03/05/1506977.shtml">
# <div class="media-box" style="background-image: url(https://pics.utro.ru/utro_photos/2022/03/05/1506977big.jpg)">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/05/1506977big.jpg"/>
# </div>
# <h4 class="news-center__top-title" data-vr-headline="">Отменят уголовное наказание: Россия придумала новый план против западных компаний</h4>
# </a>
# <p>Пока проект находится на стадии обсуждения</p>
# </div>
# <ul class="news-block__list">
# <li data-vr-contentbox="Position 2" data-vr-contentbox-url="https://utro.ru/news/life/2022/03/05/1506983.shtml">
# <a data-vr-headline="" href="/news/life/2022/03/05/1506983.shtml">Жители Закарпатья возмутились бессовестным поведением киевских беженцев </a>
# </li>
# <li data-vr-contentbox="Position 3" data-vr-contentbox-url="https://utro.ru/news/politics/2022/03/05/1506993.shtml">
# <a data-vr-headline="" href="/news/politics/2022/03/05/1506993.shtml">Илон Маск резко ответил на требование заблокировать российские СМИ</a>
# </li>
# <li data-vr-contentbox="Position 4" data-vr-contentbox-url="https://utro.ru/news/life/2022/03/04/1506887.shtml">
# <a data-vr-headline="" href="/news/life/2022/03/04/1506887.shtml">Хлопнувший дверью перед носом хозяина пес поразил зрителей своей независимостью</a>
# </li>
# </ul>
# </div>
# <div class="news-center__item _item-shadow">
# <div class="news-center__top" data-vr-contentbox="Position 1" data-vr-contentbox-url="https://utro.ru/news/ukraine/2022/03/05/1506978.shtml">
# <a href="/news/ukraine/2022/03/05/1506978.shtml">
# <div class="media-box" style="background-image: url(https://pics.utro.ru/utro_photos/2022/03/05/1506978big.jpg)">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/05/1506978big.jpg"/>
# </div>
# <h4 class="news-center__top-title" data-vr-headline="">Германия планирует спихнуть Украине вышедшее из строя вооружение - Der Spiegel</h4>
# </a>
# <p>Берлин хочет передать Киеву ПЗРК "Стрела"</p>
# </div>
# <ul class="news-block__list">
# <li data-vr-contentbox="Position 2" data-vr-contentbox-url="https://utro.ru/news/politics/2022/03/05/1506989.shtml">
# <a data-vr-headline="" href="/news/politics/2022/03/05/1506989.shtml">Россия выйдет победителем из санкционной войны с Западом - FT</a>
# </li>
# <li data-vr-contentbox="Position 3" data-vr-contentbox-url="https://utro.ru/news/life/2022/03/04/1506903.shtml">
# <a data-vr-headline="" href="/news/life/2022/03/04/1506903.shtml">Дешевые виниры превратили англичанку в Джима Керри из "Маски" — видео </a>
# </li>
# <li data-vr-contentbox="Position 4" data-vr-contentbox-url="https://utro.ru/news/horoscope/2022/02/28/1506375.shtml">
# <a data-vr-headline="" href="/news/horoscope/2022/02/28/1506375.shtml">Гороскоп на неделю с 28 февраля по 6 марта</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
#
#
# <div class="layout-two-column__aside">
# <div class="_inner-fly">
# <div class="_block">
# <!--AdFox START-->
# <!--utroru15-->
# <!--Площадка: utro.ru десктоп / * / *-->
# <!--Тип баннера: desktop 6. 300х400-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_15326354373794136"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
#         ownerId: 275069,
#         containerId: 'adfox_15326354373794136',
#         params: {
#             pp: 'g',
#             ps: 'cxhg',
#             p2: 'gatn'
#         }
#     });
# });
# </script>
# </div>
# <div class="_block">
# <div class="news-block">
# <h4 class="news-block__title">Выбор редакции</h4>
# <ul class="news-listing__chosen">
# <li>
# <a href="/news/ukraine/2022/03/06/1507082.shtml">
# <span class="news-block__list-title">Эрдоган на эмоциях поговорил с Путиным <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/politics/2022/03/06/1507090.shtml">
# <span class="news-block__list-title">Германии предсказали "плохой" или "очень плохой" конец из-за России <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/showbiz/2022/03/06/1507071.shtml">
# <span class="news-block__list-title">Пугачева и Галкин после побега получили удар от российского ТВ  <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/showbiz/2022/03/04/1506879.shtml">
# <span class="news-block__list-title">Тело пролежало в квартире два дня: в Москве умерла известная певица <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="_block">
# <div class="news-block">
# <h4 class="news-block__title">Новости партнеров</h4>
# <div id="smi_teaser_10958">
# <center><a href="http://ex.24smi.info">новости</a></center>
# </div>
# <script encoding="utf8" type="text/JavaScript">
# (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push(function() {
#  var sm = document.createElement("script");
#  sm.type = "text/javascript";
#  sm.async = true;
#  sm.src = "//jsn.24smi.net/4/a/10958.js";
#  var s = document.getElementsByTagName("script")[0];
#  s.parentNode.insertBefore(sm, s);
#     });
# })(this, "utroCallbacks");
# </script>
# </div>
# </div>
# <div class="_block">
# <div class="news-block">
# <h4 class="news-block__title">Самое читаемое</h4>
# <ul class="news-listing__chosen">
# <li>
# <a href="/news/politics/2022/02/19/1505650.shtml">
# <span class="news-block__list-title">Войны России с Украиной не будет: политолог раскрыл сдерживающий Киев фактор <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/politics/2022/02/20/1505702.shtml">
# <span class="news-block__list-title">Российский политик заявил о готовности переметнуться на сторону Украины в случае войны <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/sport/2022/02/17/1505489.shtml">
# <span class="news-block__list-title">Довели до истерики: Трусова в слезах решила отказаться от спорта <i class="icon-hasvideo"></i><!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/politics/2022/02/18/1505607.shtml">
# <span class="news-block__list-title">Украинские журналисты раскрыли возможные причины эвакуации жителей ДНР и ЛНР <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# <li>
# <a href="/news/sport/2022/02/17/1505503.shtml">
# <span class="news-block__list-title">Проиграла специально: журналисты раскрыли маневр Валиевой на Олимпиаде <!-- <i class="icon-exclamation"></i> --></span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="_block">
# <div class="news-block">
# <h4 class="news-block__title">Рекомендуем</h4>
# <ul class="news-block__list">
# <li>
# <a href="/news/showbiz/2022/03/07/1507119.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/07/1507119norm.jpg"/>
# <span class="news-block__list-title">Замок Пугачевой и Галкина выставили на продажу - Разин</span>
# </a>
# </li>
# <li>
# <a href="/news/showbiz/2022/03/07/1507118.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/07/1507118norm.jpg"/>
# <span class="news-block__list-title">Кого из звезд заочно арестовали на Украине за поддержку спецоперации</span>
# </a>
# </li>
# <li>
# <a href="/news/showbiz/2022/03/07/1507107.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/07/1507107norm.jpg"/>
# <span class="news-block__list-title">"Светлая память": народ скорбит о безвременной кончине Цискаридзе</span>
# </a>
# </li>
# <li>
# <a href="/news/horoscope/2022/03/07/1507081.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/06/1507081norm.jpg"/>
# <span class="news-block__list-title">Гороскоп на неделю с 7 по 13 марта</span>
# </a>
# </li>
# </ul>
# </div>
# </div>
# <div class="_block">
# <!--AdFox START-->
# <!--utroru15-->
# <!--Площадка: utro.ru десктоп / * / *-->
# <!--Тип баннера: desktop 7. 300х250-->
# <!--Расположение: <середина страницы>-->
# <div id="adfox_153263550155581761"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
#         ownerId: 275069,
#         containerId: 'adfox_153263550155581761',
#         params: {
#             pp: 'h',
#             ps: 'cxhg',
#             p2: 'gato'
#         }
#     });
# });
# </script>
# </div>
# <div class="_block">
# <div class="news-block">
# <div id="unit_89670"><a href="http://smi2.ru/">Новости smi2.ru</a></div>
# <script charset="utf-8" type="text/javascript">
# (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push(function() {
#     var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true;
#     sc.src = '//smi2.ru/data/js/89670.js'; sc.charset = 'utf-8';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s);
#     });
# })(this, "utroCallbacks");
# </script>
# </div>
# </div>
# <div class="_block">
# </div>
# </div>
# </div>
#
# <div class="news-group _inner">
# <div class="news-group__content">
# <div class="news-group__content">
# <div class="news-group__item" data-vr-zone="Section blocks Новости Украины">
# <div class="news-block">
# <h4 class="news-block__title">Новости Украины</h4>
# <ul class="news-block__list">
# <li>
# <a data-vr-contentbox="Position 1" data-vr-contentbox-url="https://utro.ru/news/politics/2022/03/05/1506979.shtml" href="/news/politics/2022/03/05/1506979.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/05/1506979norm.jpg">
# <span class="news-block__list-title" data-vr-headline="">Эксперт объяснила состояние Зеленского на скандальном интервью - дело не в препаратах</span>
# </img></a>
# </li>
# <li>
# <a data-vr-contentbox="Position 2" data-vr-contentbox-url="https://utro.ru/news/ukraine/2022/03/04/1506970.shtml" href="/news/ukraine/2022/03/04/1506970.shtml">
# <span class="news-block__list-title" data-vr-headline="">Израильское ТВ выдало корабль из "Звездных войн" за сбитый истребитель на Украине - видео</span>
# </a>
# </li>
# <li>
# <a data-vr-contentbox="Position 3" data-vr-contentbox-url="https://utro.ru/news/ukraine/2022/03/04/1506960.shtml" href="/news/ukraine/2022/03/04/1506960.shtml">
# <span class="news-block__list-title" data-vr-headline="">Украинский депутат сдал Зеленского</span>
# </a>
# </li>
# <li>
# <a data-vr-contentbox="Position 4" data-vr-contentbox-url="https://utro.ru/news/ukraine/2022/03/04/1506959.shtml" href="/news/ukraine/2022/03/04/1506959.shtml">
# <span class="news-block__list-title" data-vr-headline="">Во двор дачи Зеленского под Киевом упал обломок ракеты</span>
# </a>
# </li>
# </ul>
# <a class="news-block___more not-medium" href="/online/ukraine.shtml">Все новости раздела</a>
# </div>
# </div>
# <div class="news-group__item">
# <div class="banner">
# <!--AdFox START-->
# <!--utroru15-->
# <!--Площадка: utro.ru десктоп / * / *-->
# <!--Тип баннера: desktop 5. 300х600-->
# <!--Расположение: <середина страницы>-->
# <div id="adfox_153263525493889471"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
#         ownerId: 275069,
#         containerId: 'adfox_153263525493889471',
#         params: {
#             pp: 'h',
#             ps: 'cxhg',
#             p2: 'gatm'
#         }
#     });
# });
# </script>
# </div>
# </div>
# <div class="clearfix only-medium"></div>
# <div class="news-group__item" data-vr-zone="Section blocks Шоу-бизнес">
# <div class="news-block">
# <h4 class="news-block__title">Шоу-бизнес</h4>
# <ul class="news-block__list">
# <li>
# <a data-vr-contentbox="Position 1" data-vr-contentbox-url="https://utro.ru/news/showbiz/2022/03/06/1507075.shtml" href="/news/showbiz/2022/03/06/1507075.shtml">
# <img alt="" src="https://pics.utro.ru/utro_photos/2022/03/06/1507075norm.jpg">
# <span class="news-block__list-title" data-vr-headline="">Киркоров попал в больницу</span>
# </img></a>
# </li>
# <li>
# <a data-vr-contentbox="Position 2" data-vr-contentbox-url="https://utro.ru/news/showbiz/2022/03/07/1507104.shtml" href="/news/showbiz/2022/03/07/1507104.shtml">
# <span class="news-block__list-title" data-vr-headline="">Как выглядит маленькая внучка Осина: малышку показали на ТВ</span>
# </a>
# </li>
# <li>
# <a data-vr-contentbox="Position 3" data-vr-contentbox-url="https://utro.ru/news/showbiz/2022/03/07/1507103.shtml" href="/news/showbiz/2022/03/07/1507103.shtml">
# <span class="news-block__list-title" data-vr-headline="">До и после косметолога: как изменилась внешность российских звезд</span>
# </a>
# </li>
# <li>
# <a data-vr-contentbox="Position 4" data-vr-contentbox-url="https://utro.ru/news/showbiz/2022/03/05/1507058.shtml" href="/news/showbiz/2022/03/05/1507058.shtml">
# <span class="news-block__list-title" data-vr-headline="">"Не уполномочена": подруга отказалась раскрывать местонахождение Пугачевой</span>
# </a>
# </li>
# </ul>
# <a class="news-block___more not-medium" href="/showbiz.shtml">Все новости раздела</a>
# </div>
# </div>
# <div class="news-group__item" data-vr-zone="Section blocks Армия">
# <div class="news-block">
# <h4 class="news-block__title">Армия</h4>
# <ul class="news-block__list">
# <li>
# <a data-vr-contentbox="Position 1" data-vr-contentbox-url="https://utro.ru/news
# <input placeholder="Поиск" title="Поиск" type="text"/>
# <input type="submit" value="найти"/>
# </form>
# </div>
# <div class="persons-preview__list">
# <h3 class="persons-preview__title">Выбор читателей</h3>
# <ul>
# <li>
# <a href="/persons/efremov.shtml">
# <span class="persons-preview__list-name">Михаил Ефремов</span>
# <small>Советский и российский актер, театральный режиссер, телеведущий. </small>
# </a>
# </li>
# <li>
# <a href="/persons/putin.shtml">
# <span class="persons-preview__list-name">Владимир  Путин </span>
# <small>президент России</small>
# </a>
# </li>
# <li>
# <a href="/persons/Armen.shtml">
# <span class="persons-preview__list-name">Армен Джигарханян </span>
# <small>Актер, создатель и руководитель театра</small>
# </a>
# </li>
# <li>
# <a href="/persons/anastasiazavorotnyuk.shtml">
# <span class="persons-preview__list-name">Анастасия  Заворотнюк</span>
# <small>российская актриса театра и кино, телеведущая</small>
# </a>
# </li>
# <li>
# <a href="/persons/Lukashenko.shtml">
# <span class="persons-preview__list-name">Александр Лукашенко</span>
# <small>Президент Белоруссии</small>
# </a>
# </li>
# <li>
# <a href="/persons/Zelenskiy.shtml">
# <span class="persons-preview__list-name">Владимир Зеленский</span>
# <small>Президент Украины, шоумен</small>
# </a>
# </li>
# <li>
# <a href="/persons/Muceniece.shtml">
# <span class="persons-preview__list-name">Агата Муцениеце</span>
# <small>Актриса</small>
# </a>
# </li>
# <li>
# <a href="/persons/pugacheva.shtml">
# <span class="persons-preview__list-name">Алла Пугачева </span>
# <small>Певица, киноактриса</small>
# </a>
# </li>
# <li>
# <a href="/persons/tramp.shtml">
# <span class="persons-preview__list-name">Дональд Джон Трамп</span>
# <small>Политик, бизнесмен</small>
# </a>
# </li>
# <li>
# <a href="/persons/kirkorov.shtml">
# <span class="persons-preview__list-name">Филипп Киркоров</span>
# <small>Певец, композитор</small>
# </a>
# </li>
# <li>
# <a href="/persons/navalny.shtml">
# <span class="persons-preview__list-name">Алексей Навальный </span>
# <small>блогер, российский оппозиционер</small>
# </a>
# </li>
# <li>
# <a href="/persons/elenastepanenko.shtml">
# <span class="persons-preview__list-name">Елена Степаненко</span>
# <small>артистка эстрады, актриса, юмористка, телеведущая, пародистка, певица</small>
# </a>
# </li>
# <li>
# <a href="/persons/sobchak.shtml">
# <span class="persons-preview__list-name">Ксения Собчак</span>
# <small>Телеведущая, журналист</small>
# </a>
# </li>
# <li>
# <a href="/persons/sofiarotaru.shtml">
# <span class="persons-preview__list-name">София Ротару</span>
# <small>советская и украинская эстрадная певица и актриса.</small>
# </a>
# </li>
# <li>
# <a href="/persons/malakhov.shtml">
# <span class="persons-preview__list-name">Андрей Малахов</span>
# <small>Журналист, телеведущий</small>
# </a>
# </li>
# <li>
# <a href="/persons/galkin.shtml">
# <span class="persons-preview__list-name">Максим Галкин</span>
# <small>Артист, телеведущий</small>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
#
#
# <div class="foot-adv">
# <div class="foot__adv" id="GB_advert_5">
# <!--AdFox START-->
# <!--utroru15-->
# <!--Площадка: utro.ru десктоп / * / *-->
# <!--Тип баннера: desktop 9. Перетяжка нижняя-->
# <!--Расположение: <низ страницы>-->
# <div id="adfox_153263570491382807"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
#         ownerId: 275069,
#         containerId: 'adfox_153263570491382807',
#         params: {
#             pp: 'i',
#             ps: 'cxhg',
#             p2: 'gatq'
#         }
#     });
# });
# </script>
# </div>
# <div class="foot__adv">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# </div>
# </div>
# <footer class="footer js-mediator-footer">
# <div class="container">
# <div class="footer__column">
# <h3>Рубрики</h3>
# <ul>
# <li>
# <a href="/ukraine.shtml">Спецоперация на Украине</a>
# </li>
# <li>
# <a href="/politics.shtml">Политика</a>
# </li>
# <li>
# <a href="/online/pensii.shtml">Пенсии</a>
# </li>
# <li>
# <a href="/horoscope.shtml">Гороскоп</a>
# </li>
# <li>
# <a href="/showbiz.shtml">Шоу-бизнес</a>
# </li>
# <li>
# <a href="/pr.shtml">Пресс-релизы</a>
# </li>
# </ul>
# </div>
# <div class="footer__column">
# <h3>Разделы</h3>
# <ul>
# <li><a href="/about.shtml">об издании</a></li>
# <li><a href="https://utro.ru/promocode/">промокоды</a></li>
# </ul>
# </div>
# <div class="footer__column">
# <h3>Утро в соц. сетях</h3>
# <ul>
# <li><a href="https://www.facebook.com/gazetautro/"><i class="icon-fb"></i>Facebook</a></li>
# <li><a href="https://vk.com/na_utro_ru"><i class="icon-vk"></i>Вконтакте</a></li>
# <li><a href="https://ok.ru/utroru"><i class="icon-ok"></i>Одноклассниках</a></li>
# <li><a href="https://twitter.com/YTPO__Ru"><i class="icon-tw"></i>Twitter</a></li>
# <li><a href="https://zen.yandex.ru/ytro.ru"><i class="icon-zen"></i>Яндекс.Дзен</a></li>
# </ul>
# </div>
# <div class="footer__column">
# <h3>Контакты</h3>
# <address>
# <p>
# 		                119072, Москва, <br/>
# 		                 Берсеневский переулок, дом 2, строение 1
# 		            </p>
# <p>
# <a href="tel:+74955301313">+7 (495) 531-21-21</a><br/>
# <a href="mailto:info@utro.ru">utro@utro.ru</a>
# </p>
# <p>
# 		                По вопросам рекламы:<br/>
# <a href="tel:+74955312121">+7 (495) 531-21-21</a><br/>
# <a href="mailto:reklama@utro.ru">reklama@utro.ru</a>
# </p>
# </address>
# </div>
# <div class="clearfix"></div>
# <div class="copyright">Все права защищены © 1999-2022. "Утро"</div>
# <div class="reg-info">Свидетельство о регистрации СМИ Эл №ФС 77-79497 от 02.11.2020 г.</div>
# </div>
# </footer>
#
# <script src="/static/js/vendor/jquery-1.12.0.min.js" type="text/javascript"></script>
# <script src="/static/js/plugins.js" type="text/javascript"></script>
# <script src="/static/js/newmain.js?v3" type="text/javascript"></script>
# <script async="" src="https://yandex.ru/ads/system/context.js"></script>
# <script async="" src="//www.giraff.io/data/widget-utroru.js" type="text/javascript"></script>
# <div id="adfox_153494523073034810"></div>
# <script>
# window.yaContextCb.push(()=>{
# 	Ya.adfoxCode.create({
# 		ownerId: 275069,
# 		containerId: 'adfox_153494523073034810',
# 		params:
# 		{ pp: 'g', ps: 'cxhg', p2: 'gati' }
# 	});
# });
# </script>
# <script type="text/javascript">
#     var ttsmi2_data = { siteid: 9759, count: 'site' };
#     (function()
#     { var sc = document.createElement('script'); sc.type = 'text/javascript'; sc.async = true; sc.src = '//target.smi2.net/client/target.js'; var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(sc, s); }
#     ());
# </script>
# <noindex>
# <div class="counters" style="display: none">
# <!--LiveInternet counter-->
# <script type="text/javascript">document.write('<img src="https://counter.yadro.ru/hit?r' + escape(document.referrer) + ((typeof(screen)=='undefined')?'':';s'+screen.width+'*'+screen.height+'*'+(screen.colorDepth?screen.colorDepth:screen.pixelDepth)) + ';u' + escape(document.URL) +';i' + escape('Жж'+document.title.substring(0,80)) + ';' + Math.random() + '" width=1 height=1 alt="">')</script>
# <!--/LiveInternet-->
# <!-- begin of Top100 code -->
# <script id="top100Counter" src="https://counter.rambler.ru/top100.jcn?85047" type="text/javascript"></script>
# <noscript>
# <a href="http://top100.rambler.ru/navi/85047/">
# <img alt="Rambler's Top100" border="0" height="0" src="https://counter.rambler.ru/top100.cnt?85047" width="0">
# </img></a>
# </noscript>
# <!-- end of Top100 code -->
# </div>
# </noindex>

# %%
#grab the html tag
html = soup.select('html')
#check if our string is in it
"news" in html[0].get_text()
# Out:
# True

# %% [markdown]
# ### Try to drill down to tags you expect the text to be in
#
# We can also try to be more specific about the tags we're looking in. We would expect 'yandex.ru' to be inside links, for example.

# %%
#grab all links
links = soup.select('a')
#see how many we get
len(links)
# Out:
# 175

# %%
#loop through all the a tags we grabbed
for i in links:
  #print the link (not the text)
  print(i['href'])
  #check if the string "yandex" is in that link and print the result (True/False)
  print("yandex" in i['href'])
# Out:
# /
# False
# /online/ukraine.shtml
# False
# /ukraine.shtml
# False
# /politics.shtml
# False
# /online/pensii.shtml
# False
# /horoscope.shtml
# False
# /showbiz.shtml
# False
# /pr.shtml
# False
# /coronavirus.shtml
# False
# /life.shtml
# False
# /recepty.shtml
# False
# /online/primety.shtml
# False
# /online/crimean.shtml
# False
# /economics.shtml
# False
# /accidents.shtml
# False
# /online/ogorod.shtml
# False
# https://zen.yandex.ru/ytro.ru
# True
# https://news.google.com/publications/CAAiEOF7XMpY3eSH2Jkm8AEzhb0qFAgKIhDhe1zKWN3kh9iZJvABM4W9?hl=ru&gl=RU&ceid=RU%3Aru
# False
# /news/ukraine/2022/03/07/1507105.shtml
# False
# https://ria.ru/20220307/ukraina-1777009831.html
# False
# /author/%D0%9A%D1%80%D0%B8%D1%81%D1%82%D0%B8%D0%BD%D0%B0%20%D0%A7%D0%95%D0%A0%D0%9D%D0%98%D0%9A%D0%9E%D0%92%D0%90/
# False
# /news/ukraine/2022/03/07/1505982.shtml
# False
# /news/ukraine/2022/03/05/1507038.shtml
# False
# /persons/putin.shtml
# False
# /news/politics/2022/03/05/1506977.shtml
# False
# /news/life/2022/03/05/1506983.shtml
# False
# /news/politics/2022/03/05/1506993.shtml
# False
# /news/life/2022/03/04/1506887.shtml
# False
# /news/ukraine/2022/03/05/1506978.shtml
# False
# /news/politics/2022/03/05/1506989.shtml
# False
# /news/life/2022/03/04/1506903.shtml
# False
# /news/horoscope/2022/02/28/1506375.shtml
# False
# /news/ukraine/2022/03/06/1507082.shtml
# False
# /news/politics/2022/03/06/1507090.shtml
# False
# /news/showbiz/2022/03/06/1507071.shtml
# False
# /news/showbiz/2022/03/04/1506879.shtml
# False
# http://ex.24smi.info
# False
# /news/politics/2022/02/19/1505650.shtml
# False
# False
# /news/showbiz/2022/02/10/1504851.shtml
# False
# /news/ukraine/2022/02/25/1506149.shtml
# False
# /news/economics/2021/03/26/1477501.shtml
# False
# /news/ukraine/2022/02/25/1506235.shtml
# False
# /news/politics/2022/02/23/1505959.shtml
# False
# /news/politics/2022/02/22/1505825.shtml
# False
# /news/showbiz/2022/02/22/1505885.shtml
# False
# /news/sport/2022/02/17/1505489.shtml
# False
# /news/ukraine/2022/02/24/1506042.shtml
# False
# /news/showbiz/2022/02/24/1506075.shtml
# False
# /persons/%D0%90
# False
# /persons/%D0%91
# False
# /persons/%D0%92
# False
# /persons/%D0%93
# False
# /persons/%D0%94
# False
# /persons/%D0%95
# False
# /persons/%D0%96
# False
# /persons/%D0%97
# False
# /persons/%D0%98
# False
# /persons/%D0%9A
# False
# /persons/%D0%9B
# False
# /persons/%D0%9C
# False
# /persons/%D0%9D
# False
# /persons/%D0%9E
# False
# /persons/%D0%9F
# False
# /persons/%D0%A0
# False
# /persons/%D0%A1
# False
# /persons/%D0%A2
# False
# /persons/%D0%A3
# False
# /persons/%D0%A4
# False
# /persons/%D0%A5
# False
# /persons/%D0%A6
# False
# /persons/%D0%A7
# False
# /persons/%D0%A8
# False
# /persons/%D0%A9
# False
# /persons/%D0%AD
# False
# /persons/%D0%AE
# False
# /persons/%D0%AF
# False
# /persons/efremov.shtml
# False
# /persons/putin.shtml
# False
# /persons/Armen.shtml
# False
# /persons/anastasiazavorotnyuk.shtml
# False
# /persons/Lukashenko.shtml
# False
# /persons/Zelenskiy.shtml
# False
# /persons/Muceniece.shtml
# False
# /persons/pugacheva.shtml
# False
# /persons/tramp.shtml
# False
# /persons/kirkorov.shtml
# False
# /persons/navalny.shtml
# False
# /persons/elenastepanenko.shtml
# False
# /persons/sobchak.shtml
# False
# /persons/sofiarotaru.shtml
# False
# /persons/malakhov.shtml
# False
# /persons/galkin.shtml
# False
# /ukraine.shtml
# False
# /politics.shtml
# False
# /online/pensii.shtml
# False
# /horoscope.shtml
# False
# /showbiz.shtml
# False
# /pr.shtml
# False
# /about.shtml
# False
# https://utro.ru/promocode/
# False
# https://www.facebook.com/gazetautro/
# False
# https://vk.com/na_utro_ru
# False
# https://ok.ru/utroru
# False
# https://twitter.com/YTPO__Ru
# False
# https://zen.yandex.ru/ytro.ru
# True
# tel:+74955301313
# False
# mailto:info@utro.ru
# False
# tel:+74955312121
# False
# mailto:reklama@utro.ru
# False
# http://top100.rambler.ru/navi/85047/
# False

# %% [markdown]
# ### Use an `if` test to only show results that match
#
# We might not want to watch 175 results go past or scan through the results to find what we're after.
#
# Instead, then, we can add an `if` to our loop which only prints the match *if* our string is in the match.

# %%
#loop through all the a tags we grabbed
for i in links:
  #check if the string "yandex" is in that link and store the result (True/False)
  yandextf = "yandex" in i['href']
  #only if it is True
  if yandextf == True:
    #print the matched a (tag and contents)
    print(i)
# Out:
# <a href="https://zen.yandex.ru/ytro.ru" target="_blank"><i class="icon-yandex"></i></a>
# <a href="https://zen.yandex.ru/ytro.ru"><i class="icon-zen"></i>Яндекс.Дзен</a>
